# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
pd.set_option('display.max_rows', None)

# %%
pattern = r"[A-Z]+"

all_list = os.listdir('dogs_breed_0820')
ttv = []
breed = []
count = []
for cate in all_list:
    folder_list = os.listdir(os.path.join('dogs_breed_0820', cate))
    for folder in folder_list:
        ttv.append(cate)
        breed.append(' '.join(re.findall(pattern, folder[1:])))
        count.append(len(os.listdir(os.path.join('dogs_breed_0820', cate, folder))))

# %%
# to dataframe
df = pd.DataFrame([ttv, breed, count]).T
df.columns = ['set', 'breed', 'count']
df
# Out:
#       set                    breed count
# 0    test             BICHON FRISE    56
# 1    test               POMERANIAN    60
# 2    test           FRENCH BULLDOG    48
# 3    test                CHIHUAHUA    60
# 4    test                  MALTESE    60
# 5    test               TOY POODLE    56
# 6    test       LABRADOR RETRIEVER    59
# 7    test           BABY JINDI DOG    49
# 8    test          KOREA JINDO DOG    60
# 9    test       ITALIAN GREY HOUND    52
# 10   test              WELSH CORGI    60
# 11   test                  BULLDOG    60
# 12   test        SHETLAND SHEEPDOG    60
# 13   test                    SHIBA    57
# 14   test         GOLDEN RETRIEVER    53
# 15   test               ROTTWEILER    58
# 16   test                      PUG    60
# 17   test       BEDLINGTON TERRIER    60
# 18   test      GERMAN SHEPHERD DOG    60
# 19   test                CHOW CHOW    60
# 20   test                DOBERMANN    60
# 21   test  AMERICAN COCKER SPANIEL    60
# 22   test  CAVALIER COCKER SPANIEL    56
# 23   test                PEKINGESE    54
# 24   test          STANDARD POODLE    60
# 25   test        YORKSHIRE TERRIER    60
# 26   test                  SAMOYED    60
# 27   test                    HUSKY    51
# 28   test                 SHIH TZU    60
# 29   test                    SPITZ    60
# 30  train             BICHON FRISE   170
# 31  train               POMERANIAN   180
# 32  train           FRENCH BULLDOG   143
# 33  train                CHIHUAHUA   180
# 34  train                  MALTESE   180
# 35  train               TOY POODLE   170
# 36  train       LABRADOR RETRIEVER   177
# 37  train           BABY JINDI DOG   146
# 38  train          KOREA JINDO DOG   180
# 39  train       ITALIAN GREY HOUND   154
# 40  train              WELSH CORGI   180
# 41  train                  BULLDOG   180
# 42  train        SHETLAND SHEEPDOG   180
# 43  train                    SHIBA   171
# 44  train         GOLDEN RETRIEVER   161
# 45  train               ROTTWEILER   174
# 46  train                      PUG   180
# 47  train       BEDLINGTON TERRIER   178
# 48  train      GERMAN SHEPHERD DOG   180
# 49  train                CHOW CHOW   180
# 50  train                DOBERMANN   180
# 51  train  AMERICAN COCKER SPANIEL   180
# 52  train  CAVALIER COCKER SPANIEL   168
# 53  train                PEKINGESE   163
# 54  train          STANDARD POODLE   180
# 55  train        YORKSHIRE TERRIER   180
# 56  train                  SAMOYED   180
# 57  train                    HUSKY   154
# 58  train                 SHIH TZU   180
# 59  train                    SPITZ   180
# 60  valid             BICHON FRISE    56
# 61  valid               POMERANIAN    60
# 62  valid           FRENCH BULLDOG    48
# 63  valid                CHIHUAHUA    60
# 64  valid                  MALTESE    60
# 65  valid               TOY POODLE    56
# 66  valid       LABRADOR RETRIEVER    59
# 67  valid           BABY JINDI DOG    49
# 68  valid          KOREA JINDO DOG    60
# 69  valid       ITALIAN GREY HOUND    52
# 70  valid              WELSH CORGI    60
# 71  valid                  BULLDOG    60
# 72  valid        SHETLAND SHEEPDOG    60
# 73  valid                    SHIBA    57
# 74  valid         GOLDEN RETRIEVER    53
# 75  valid               ROTTWEILER    58
# 76  valid                      PUG    60
# 77  valid       BEDLINGTON TERRIER    59
# 78  valid      GERMAN SHEPHERD DOG    60
# 79  valid                CHOW CHOW    60
# 80  valid                DOBERMANN    60
# 81  valid  AMERICAN COCKER SPANIEL    60
# 82  valid  CAVALIER COCKER SPANIEL    56
# 83  valid                PEKINGESE    54
# 84  valid          STANDARD POODLE    60
# 85  valid        YORKSHIRE TERRIER    60
# 86  valid                  SAMOYED    60
# 87  valid                    HUSKY    51
# 88  valid                 SHIH TZU    60
# 89  valid                    SPITZ    60

# %%
# 품종별 개수
df.sort_values(by=['breed', 'set'], axis=0).set_index(['breed', 'set'])
# Out:
#                               count
# breed                   set
# AMERICAN COCKER SPANIEL test     60
#                         train   180
#                         valid    60
# BABY JINDI DOG          test     49
#                         train   146
#                         valid    49
# BEDLINGTON TERRIER      test     60
#                         train   178
#                         valid    59
# BICHON FRISE            test     56
#                         train   170
#                         valid    56
# BULLDOG                 test     60
#                         train   180
#                         valid    60
# CAVALIER COCKER SPANIEL test     56
#                         train   168
#                         valid    56
# CHIHUAHUA               test     60
#                         train   180
#                         valid    60
# CHOW CHOW               test     60
#                         train   180
#                         valid    60
# DOBERMANN               test     60
#                         train   180
#                         valid    60
# FRENCH BULLDOG          test     48
#                         train   143
#                         valid    48
# GERMAN SHEPHERD DOG     test     60
#                         train   180
#                         valid    60
# GOLDEN RETRIEVER        test     53
#                         train   161
#                         valid    53
# HUSKY                   test     51
#                         train   154
#                         valid    51
# ITALIAN GREY HOUND      test     52
#                         train   154
#                         valid    52
# KOREA JINDO DOG         test     60
#                         train   180
#                         valid    60
# LABRADOR RETRIEVER      test     59
#                         train   177
#                         valid    59
# MALTESE                 test     60
#                         train   180
#                         valid    60
# PEKINGESE               test     54
#                         train   163
#                         valid    54
# POMERANIAN              test     60
#                         train   180
#                         valid    60
# PUG                     test     60
#                         train   180
#                         valid    60
# ROTTWEILER              test     58
#                         train   174
#                         valid    58
# SAMOYED                 test     60
#                         train   180
#                         valid    60
# SHETLAND SHEEPDOG       test     60
#                         train   180
#                         valid    60
# SHIBA                   test     57
#                         train   171
#                         valid    57
# SHIH TZU                test     60
#                         train   180
#                         valid    60
# SPITZ                   test     60
#                         train   180
#                         valid    60
# STANDARD POODLE         test     60
#                         train   180
#                         valid    60
# TOY POODLE              test     56
#                         train   170
#                         valid    56
# WELSH CORGI             test     60
#                         train   180
#                         valid    60
# YORKSHIRE TERRIER       test     60
#                         train   180
#                         valid    60

# %%
# 용도별 개수
df.sort_values(by=['set', 'breed'], axis=0).set_index(['set', 'breed'])
# Out:
#                               count
# set   breed
# test  AMERICAN COCKER SPANIEL    60
#       BABY JINDI DOG             49
#       BEDLINGTON TERRIER         60
#       BICHON FRISE               56
#       BULLDOG                    60
#       CAVALIER COCKER SPANIEL    56
#       CHIHUAHUA                  60
#       CHOW CHOW                  60
#       DOBERMANN                  60
#       FRENCH BULLDOG             48
#       GERMAN SHEPHERD DOG        60
#       GOLDEN RETRIEVER           53
#       HUSKY                      51
#       ITALIAN GREY HOUND         52
#       KOREA JINDO DOG            60
#       LABRADOR RETRIEVER         59
#       MALTESE                    60
#       PEKINGESE                  54
#       POMERANIAN                 60
#       PUG                        60
#       ROTTWEILER                 58
#       SAMOYED                    60
#       SHETLAND SHEEPDOG          60
#       SHIBA                      57
#       SHIH TZU                   60
#       SPITZ                      60
#       STANDARD POODLE            60
#       TOY POODLE                 56
#       WELSH CORGI                60
#       YORKSHIRE TERRIER          60
# train AMERICAN COCKER SPANIEL   180
#       BABY JINDI DOG            146
#       BEDLINGTON TERRIER        178
#       BICHON FRISE              170
#       BULLDOG                   180
#       CAVALIER COCKER SPANIEL   168
#       CHIHUAHUA                 180
#       CHOW CHOW                 180
#       DOBERMANN                 180
#       FRENCH BULLDOG            143
#       GERMAN SHEPHERD DOG       180
#       GOLDEN RETRIEVER          161
#       HUSKY                     154
#       ITALIAN GREY HOUND        154
#       KOREA JINDO DOG           180
#       LABRADOR RETRIEVER        177
#       MALTESE                   180
#       PEKINGESE                 163
#       POMERANIAN                180
#       PUG                       180
#       ROTTWEILER                174
#       SAMOYED                   180
#       SHETLAND SHEEPDOG         180
#       SHIBA                     171
#       SHIH TZU                  180
#       SPITZ                     180
#       STANDARD POODLE           180
#       TOY POODLE                170
#       WELSH CORGI               180
#       YORKSHIRE TERRIER         180
# valid AMERICAN COCKER SPANIEL    60
#       BABY JINDI DOG             49
#       BEDLINGTON TERRIER         59
#       BICHON FRISE               56
#       BULLDOG                    60
#       CAVALIER COCKER SPANIEL    56
#       CHIHUAHUA                  60
#       CHOW CHOW                  60
#       DOBERMANN                  60
#       FRENCH BULLDOG             48
#       GERMAN SHEPHERD DOG        60
#       GOLDEN RETRIEVER           53
#       HUSKY                      51
#       ITALIAN GREY HOUND         52
#       KOREA JINDO DOG            60
#       LABRADOR RETRIEVER         59
#       MALTESE                    60
#       PEKINGESE                  54
#       POMERANIAN                 60
#       PUG                        60
#       ROTTWEILER                 58
#       SAMOYED                    60
#       SHETLAND SHEEPDOG          60
#       SHIBA                      57
#       SHIH TZU                   60
#       SPITZ                      60
#       STANDARD POODLE            60
#       TOY POODLE                 56
#       WELSH CORGI                60
#       YORKSHIRE TERRIER          60

# %%
# 비율
df['set_in_breed_ratio'] = df['count']/df.groupby('breed')['count'].sum().loc[df['breed']].values*100 # 품종 내 set 비중
df['breed_in_set_ratio'] = df['count']/df.groupby('set')['count'].sum().loc[df['set']].values*100 # set 내 품종 비중

# 품종별
df.sort_values(by=['breed', 'set'], axis=0).set_index(['breed', 'set'])
# Out:
#                               count set_in_breed_ratio breed_in_set_ratio
# breed                   set
# AMERICAN COCKER SPANIEL test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# BABY JINDI DOG          test     49             20.082            2.83401
#                         train   146            59.8361            2.81364
#                         valid    49             20.082            2.83565
# BEDLINGTON TERRIER      test     60             20.202            3.47021
#                         train   178            59.9327            3.43033
#                         valid    59            19.8653            3.41435
# BICHON FRISE            test     56            19.8582            3.23887
#                         train   170            60.2837            3.27616
#                         valid    56            19.8582            3.24074
# BULLDOG                 test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# CAVALIER COCKER SPANIEL test     56                 20            3.23887
#                         train   168                 60            3.23762
#                         valid    56                 20            3.24074
# CHIHUAHUA               test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# CHOW CHOW               test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# DOBERMANN               test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# FRENCH BULLDOG          test     48            20.0837            2.77617
#                         train   143            59.8326            2.75583
#                         valid    48            20.0837            2.77778
# GERMAN SHEPHERD DOG     test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# GOLDEN RETRIEVER        test     53            19.8502            3.06536
#                         train   161            60.2996            3.10272
#                         valid    53            19.8502            3.06713
# HUSKY                   test     51            19.9219            2.94968
#                         train   154            60.1562            2.96782
#                         valid    51            19.9219            2.95139
# ITALIAN GREY HOUND      test     52             20.155            3.00752
#                         train   154            59.6899            2.96782
#                         valid    52             20.155            3.00926
# KOREA JINDO DOG         test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# LABRADOR RETRIEVER      test     59                 20            3.41238
#                         train   177                 60            3.41106
#                         valid    59                 20            3.41435
# MALTESE                 test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# PEKINGESE               test     54            19.9262            3.12319
#                         train   163            60.1476            3.14126
#                         valid    54            19.9262              3.125
# POMERANIAN              test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# PUG                     test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# ROTTWEILER              test     58                 20            3.35454
#                         train   174                 60            3.35325
#                         valid    58                 20            3.35648
# SAMOYED                 test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# SHETLAND SHEEPDOG       test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# SHIBA                   test     57                 20             3.2967
#                         train   171                 60            3.29543
#                         valid    57                 20            3.29861
# SHIH TZU                test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# SPITZ                   test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# STANDARD POODLE         test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# TOY POODLE              test     56            19.8582            3.23887
#                         train   170            60.2837            3.27616
#                         valid    56            19.8582            3.24074
# WELSH CORGI             test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222
# YORKSHIRE TERRIER       test     60                 20            3.47021
#                         train   180                 60            3.46888
#                         valid    60                 20            3.47222

# %%
# 용도별
df.sort_values(by=['set', 'breed'], axis=0).set_index(['set', 'breed'])
# Out:
#                               count set_in_breed_ratio breed_in_set_ratio
# set   breed
# test  AMERICAN COCKER SPANIEL    60                 20            3.47021
#       BABY JINDI DOG             49             20.082            2.83401
#       BEDLINGTON TERRIER         60             20.202            3.47021
#       BICHON FRISE               56            19.8582            3.23887
#       BULLDOG                    60                 20            3.47021
#       CAVALIER COCKER SPANIEL    56                 20            3.23887
#       CHIHUAHUA                  60                 20            3.47021
#       CHOW CHOW                  60                 20            3.47021
#       DOBERMANN                  60                 20            3.47021
#       FRENCH BULLDOG             48            20.0837            2.77617
#       GERMAN SHEPHERD DOG        60                 20            3.47021
#       GOLDEN RETRIEVER           53            19.8502            3.06536
#       HUSKY                      51            19.9219            2.94968
#       ITALIAN GREY HOUND         52             20.155            3.00752
#       KOREA JINDO DOG            60                 20            3.47021
#       LABRADOR RETRIEVER         59                 20            3.41238
#       MALTESE                    60                 20            3.47021
#       PEKINGESE                  54            19.9262            3.12319
#       POMERANIAN                 60                 20            3.47021
#       PUG                        60                 20            3.47021
#       ROTTWEILER                 58                 20            3.35454
#       SAMOYED                    60                 20            3.47021
#       SHETLAND SHEEPDOG          60                 20            3.47021
#       SHIBA                      57                 20             3.2967
#       SHIH TZU                   60                 20            3.47021
#       SPITZ                      60                 20            3.47021
#       STANDARD POODLE            60                 20            3.47021
#       TOY POODLE                 56            19.8582            3.23887
#       WELSH CORGI                60                 20            3.47021
#       YORKSHIRE TERRIER          60                 20            3.47021
# train AMERICAN COCKER SPANIEL   180                 60            3.46888
#       BABY JINDI DOG            146            59.8361            2.81364
#       BEDLINGTON TERRIER        178            59.9327            3.43033
#       BICHON FRISE              170            60.2837            3.27616
#       BULLDOG                   180                 60            3.46888
#       CAVALIER COCKER SPANIEL   168                 60            3.23762
#       CHIHUAHUA                 180                 60            3.46888
#       CHOW CHOW                 180                 60            3.46888
#       DOBERMANN                 180                 60            3.46888
#       FRENCH BULLDOG            143            59.8326            2.75583
#       GERMAN SHEPHERD DOG       180                 60            3.46888
#       GOLDEN RETRIEVER          161            60.2996            3.10272
#       HUSKY                     154            60.1562            2.96782
#       ITALIAN GREY HOUND        154            59.6899            2.96782
#       KOREA JINDO DOG           180                 60            3.46888
#       LABRADOR RETRIEVER        177                 60            3.41106
#       MALTESE                   180                 60            3.46888
#       PEKINGESE                 163            60.1476            3.14126
#       POMERANIAN                180                 60            3.46888
#       PUG                       180                 60            3.46888
#       ROTTWEILER                174                 60            3.35325
#       SAMOYED                   180                 60            3.46888
#       SHETLAND SHEEPDOG         180                 60            3.46888
#       SHIBA                     171                 60            3.29543
#       SHIH TZU                  180                 60            3.46888
#       SPITZ                     180                 60            3.46888
#       STANDARD POODLE           180                 60            3.46888
#       TOY POODLE                170            60.2837            3.27616
#       WELSH CORGI               180                 60            3.46888
#       YORKSHIRE TERRIER         180                 60            3.46888
# valid AMERICAN COCKER SPANIEL    60                 20            3.47222
#       BABY JINDI DOG             49             20.082            2.83565
#       BEDLINGTON TERRIER         59            19.8653            3.41435
#       BICHON FRISE               56            19.8582            3.24074
#       BULLDOG                    60                 20            3.47222
#       CAVALIER COCKER SPANIEL    56                 20            3.24074
#       CHIHUAHUA                  60                 20            3.47222
#       CHOW CHOW                  60                 20            3.47222
#       DOBERMANN                  60                 20            3.47222
#       FRENCH BULLDOG             48            20.0837            2.77778
#       GERMAN SHEPHERD DOG        60                 20            3.47222
#       GOLDEN RETRIEVER           53            19.8502            3.06713
#       HUSKY                      51            19.9219            2.95139
#       ITALIAN GREY HOUND         52             20.155            3.00926
#       KOREA JINDO DOG            60                 20            3.47222
#       LABRADOR RETRIEVER         59                 20            3.41435
#       MALTESE                    60                 20            3.47222
#       PEKINGESE                  54            19.9262              3.125
#       POMERANIAN                 60                 20            3.47222
#       PUG                        60                 20            3.47222
#       ROTTWEILER                 58                 20            3.35648
#       SAMOYED                    60                 20            3.47222
#       SHETLAND SHEEPDOG          60                 20            3.47222
#       SHIBA                      57                 20            3.29861
#       SHIH TZU                   60                 20            3.47222
#       SPITZ                      60                 20            3.47222
#       STANDARD POODLE            60                 20            3.47222
#       TOY POODLE                 56            19.8582            3.24074
#       WELSH CORGI                60                 20            3.47222
#       YORKSHIRE TERRIER          60                 20            3.47222

# %%
# 전체 품종별 비율
breedratio = pd.DataFrame(df.groupby('breed')['count'].sum()).reset_index()
breedratio['ratio'] = breedratio['count']/breedratio['count'].sum()*100
breedratio.sort_values(by=['ratio'], ascending=False, axis=0)
# Out:
#                       breed  count     ratio
# 0   AMERICAN COCKER SPANIEL    300  3.469813
# 14          KOREA JINDO DOG    300  3.469813
# 28              WELSH CORGI    300  3.469813
# 26          STANDARD POODLE    300  3.469813
# 25                    SPITZ    300  3.469813
# 24                 SHIH TZU    300  3.469813
# 22        SHETLAND SHEEPDOG    300  3.469813
# 21                  SAMOYED    300  3.469813
# 19                      PUG    300  3.469813
# 18               POMERANIAN    300  3.469813
# 16                  MALTESE    300  3.469813
# 29        YORKSHIRE TERRIER    300  3.469813
# 7                 CHOW CHOW    300  3.469813
# 8                 DOBERMANN    300  3.469813
# 4                   BULLDOG    300  3.469813
# 10      GERMAN SHEPHERD DOG    300  3.469813
# 6                 CHIHUAHUA    300  3.469813
# 2        BEDLINGTON TERRIER    297  3.435115
# 15       LABRADOR RETRIEVER    295  3.411982
# 20               ROTTWEILER    290  3.354152
# 23                    SHIBA    285  3.296322
# 3              BICHON FRISE    282  3.261624
# 27               TOY POODLE    282  3.261624
# 5   CAVALIER COCKER SPANIEL    280  3.238492
# 17                PEKINGESE    271  3.134397
# 11         GOLDEN RETRIEVER    267  3.088133
# 13       ITALIAN GREY HOUND    258  2.984039
# 12                    HUSKY    256  2.960907
# 1            BABY JINDI DOG    244  2.822114
# 9            FRENCH BULLDOG    239  2.764284

# %%
# 전체 set 비율
setratio = pd.DataFrame(df.groupby('set')['count'].sum()).reset_index()
setratio['ratio'] = setratio['count']/setratio['count'].sum()*100
setratio.set_index('set')
# Out:
#        count      ratio
# set
# test    1729  19.997687
# train   5189  60.016192
# valid   1728  19.986121

# %%
# donut graph
plt.figure(figsize=(40, 40))
plt.rc('font', family='NanumGothic')
plt.rcParams['font.size'] = 15
fig, ax = plt.subplots()
size = 2

cmap = plt.get_cmap("Pastel2")
outer_colors = cmap(np.arange(8))
inner_colors = cmap([1, 0, 2])

dfdf = df.sort_values(by=['breed', 'set'], axis=0)
temp = pd.DataFrame(dfdf.groupby('breed')['count'].sum()).reset_index()

ax.pie(dfdf['count'], labels=dfdf['set'], radius=5-size, colors=inner_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=1, startangle=90)
ax.pie(temp['count'], labels=temp['breed'], radius=5, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=1.05, startangle=90)

plt.show()

# %%
# donut graph
plt.figure(figsize=(40, 40))
plt.rc('font', family='NanumGothic')
plt.rcParams['font.size'] = 15
fig, ax = plt.subplots()
size = 2

cmap = plt.get_cmap("Pastel2")
outer_colors = cmap(np.arange(8))
inner_colors = cmap(np.arange(8))

temp = pd.DataFrame(df.groupby('set')['count'].sum()).reset_index()

ax.pie(df['count'], radius=5-size, colors=inner_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=1, startangle=90)
ax.pie(temp['count'], labels=temp['set'], radius=5, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=0.8, startangle=90)

plt.show()

# %%
pattern1 = r"[A-Z]+"
pattern2 = r"[a-z]+"
folder_list = os.listdir(os.path.join('re_id_dataset/train_all'))

breed = []
color = []
count = []

for folder in folder_list:
    breed.append(' '.join(re.findall(pattern1, folder[1:])))
    color.append(' '.join(re.findall(pattern2, folder[1:])))
    count.append(len(os.listdir(os.path.join('re_id_dataset/train_all', folder))))

# %%
# to dataframe
df = pd.DataFrame([breed, color, count]).T
df.columns = ['breed', 'color', 'count']
df = df.sort_values(by=['breed', 'color'], axis=0).reset_index().drop('index', axis=1)

# %%
# 비율
df['ratio'] = df['count']/sum(df['count'])
df
# Out:
#                       breed              color count       ratio
# 0   AMERICAN COCKER SPANIEL          all black    34    0.012806
# 1   AMERICAN COCKER SPANIEL          all brown    34    0.012806
# 2   AMERICAN COCKER SPANIEL          all white    25   0.0094162
# 3   AMERICAN COCKER SPANIEL        black white    31   0.0116761
# 4        BEDLINGTON TERRIER               grey    27   0.0101695
# 5        BEDLINGTON TERRIER              white    34    0.012806
# 6                    BICHON            white m    28   0.0105461
# 7                    BICHON            white o    32   0.0120527
# 8                   BULLDOG        black white    26  0.00979284
# 9                   BULLDOG        brown white    39   0.0146893
# 10                  BULLDOG              white    34    0.012806
# 11  CAVALIER COCKER SPANIEL                big    37    0.013936
# 12  CAVALIER COCKER SPANIEL              small    29   0.0109228
# 13                CHIHUAHUA          all black    31   0.0116761
# 14                CHIHUAHUA          all brown    27   0.0101695
# 15                CHIHUAHUA          all white    31   0.0116761
# 16                CHIHUAHUA        black brown    27   0.0101695
# 17                CHIHUAHUA        black white    26  0.00979284
# 18                CHIHUAHUA        brown white    32   0.0120527
# 19                CHOW CHOW              black    36   0.0135593
# 20                CHOW CHOW              brown    36   0.0135593
# 21                CHOW CHOW              white    34    0.012806
# 22                DOBERMANN        black brown    32   0.0120527
# 23           FRENCH BULLDOG          all black    32   0.0120527
# 24           FRENCH BULLDOG          all white    38   0.0143126
# 25           FRENCH BULLDOG  black chest white    36   0.0135593
# 26           FRENCH BULLDOG        black white    43   0.0161959
# 27           FRENCH BULLDOG  brown mouth black    31   0.0116761
# 28      GERMAN SHEPHERD DOG        black brown    32   0.0120527
# 29         GOLDEN RETRIEVER              brown    34    0.012806
# 30         GOLDEN RETRIEVER        light brown    27   0.0101695
# 31         GOLDEN RETRIEVER              white    31   0.0116761
# 32                    HUSKY        black white    38   0.0143126
# 33                    HUSKY         grey white    29   0.0109228
# 34       ITALIAN GREY HOUND              black    30   0.0112994
# 35       ITALIAN GREY HOUND              brown    22  0.00828625
# 36       ITALIAN GREY HOUND               grey    36   0.0135593
# 37                    JINDO      all brown big    40   0.0150659
# 38                    JINDO    all brown small    32   0.0120527
# 39                    JINDO      all white big    34    0.012806
# 40                    JINDO    all white small    38   0.0143126
# 41                    JINDO    black brown big    29   0.0109228
# 42                    JINDO  black brown small    28   0.0105461
# 43                 LABRADOR          all black    41   0.0154426
# 44                 LABRADOR          all white    42   0.0158192
# 45                 LABRADOR         all yellow    34    0.012806
# 46                  MALTESE    white long hair    36   0.0135593
# 47                  MALTESE   white short hair    41   0.0154426
# 48                PEKINGESE          all black    34    0.012806
# 49                PEKINGESE          all brown    35   0.0131827
# 50                PEKINGESE          all white    39   0.0146893
# 51                PEKINGESE  white mouth black    26  0.00979284
# 52               POMERANIAN          all black    26  0.00979284
# 53               POMERANIAN          all brown    34    0.012806
# 54               POMERANIAN          all white    33   0.0124294
# 55               POMERANIAN        black brown    25   0.0094162
# 56               POMERANIAN        black white    41   0.0154426
# 57               POMERANIAN        brown white    28   0.0105461
# 58                      PUG              black    37    0.013936
# 59                      PUG  white mouth black    35   0.0131827
# 60               ROTTWEILER        black brown    37    0.013936
# 61                  SAMOYED          white big    31   0.0116761
# 62        SHETLAND SHEEPDOG        black white    28   0.0105461
# 63        SHETLAND SHEEPDOG           tricolor    39   0.0146893
# 64                    SHIBA        black white    29   0.0109228
# 65                    SHIBA        brown white    37    0.013936
# 66                    SHIBA              white    23   0.0086629
# 67                 SHIH TZU          all white    29   0.0109228
# 68                 SHIH TZU          white o o    30   0.0112994
# 69                    SPITZ          white big    39   0.0146893
# 70                    SPITZ        white small    29   0.0109228
# 71          STANDARD POODLE          all black    39   0.0146893
# 72          STANDARD POODLE          all brown    31   0.0116761
# 73          STANDARD POODLE          all white    37    0.013936
# 74               TOY POODLE          all black    31   0.0116761
# 75               TOY POODLE          all brown    30   0.0112994
# 76               TOY POODLE          all white    30   0.0112994
# 77              WELSH CORGI        black white    31   0.0116761
# 78              WELSH CORGI        brown white    26  0.00979284
# 79              WELSH CORGI           tricolor    28   0.0105461
# 80        YORKSHIRE TERRIER          long hair    28   0.0105461
# 81        YORKSHIRE TERRIER         short hair    24  0.00903955

# %%
df2 = pd.DataFrame(df.groupby(['breed', 'color']).sum()['count'])
df2 = df2.reset_index()
df2['color_in_breed_ratio'] = df2['count']/df2.groupby('breed')['count'].sum().loc[df2['breed']].values*100 # 품종 내 color 비중
df2['breed_in_color_ratio'] = df2['count']/df2.groupby('color')['count'].sum().loc[df2['color']].values*100 # color 내 품종 비중
df2.set_index(['breed', 'color'])
# Out:
#                                            count  color_in_breed_ratio  \
# breed                   color
# AMERICAN COCKER SPANIEL all black             34             27.419355
#                         all brown             34             27.419355
#                         all white             25             20.161290
#                         black white           31             25.000000
# BEDLINGTON TERRIER      grey                  27             44.262295
#                         white                 34             55.737705
# BICHON                  white m               28             46.666667
#                         white o               32             53.333333
# BULLDOG                 black white           26             26.262626
#                         brown white           39             39.393939
#                         white                 34             34.343434
# CAVALIER COCKER SPANIEL big                   37             56.060606
#                         small                 29             43.939394
# CHIHUAHUA               all black             31             17.816092
#                         all brown             27             15.517241
#                         all white             31             17.816092
#                         black brown           27             15.517241
#                         black white           26             14.942529
#                         brown white           32             18.390805
# CHOW CHOW               black                 36             33.962264
#                         brown                 36             33.962264
#                         white                 34             32.075472
# DOBERMANN               black brown           32            100.000000
# FRENCH BULLDOG          all black             32             17.777778
#                         all white             38             21.111111
#                         black chest white     36             20.000000
#                         black white           43             23.888889
#                         brown mouth black     31             17.222222
# GERMAN SHEPHERD DOG     black brown           32            100.000000
# GOLDEN RETRIEVER        brown                 34             36.956522
#                         light brown           27             29.347826
#                         white                 31             33.695652
# HUSKY                   black white           38             56.716418
#                         grey white            29             43.283582
# ITALIAN GREY HOUND      black                 30             34.090909
#                         brown                 22             25.000000
#                         grey                  36             40.909091
# JINDO                   all brown big         40             19.900498
#                         all brown small       32             15.920398
#                         all white big         34             16.915423
#                         all white small       38             18.905473
#                         black brown big       29             14.427861
#                         black brown small     28             13.930348
# LABRADOR                all black             41             35.042735
#                         all white             42             35.897436
#                         all yellow            34             29.059829
# MALTESE                 white long hair       36             46.753247
#                         white short hair      41             53.246753
# PEKINGESE               all black             34             25.373134
#                         all brown             35             26.119403
#                         all white             39             29.104478
#                         white mouth black     26             19.402985
# POMERANIAN              all black             26             13.903743
#                         all brown             34             18.181818
#                         all white             33             17.647059
#                         black brown           25             13.368984
#                         black white           41             21.925134
#                         brown white           28             14.973262
# PUG                     black                 37             51.388889
#                         white mouth black     35             48.611111
# ROTTWEILER              black brown           37            100.000000
# SAMOYED                 white big             31            100.000000
# SHETLAND SHEEPDOG       black white           28             41.791045
#                         tricolor              39             58.208955
# SHIBA                   black white           29             32.584270
#                         brown white           37             41.573034
#                         white                 23             25.842697
# SHIH TZU                all white             29             49.152542
#                         white o o             30             50.847458
# SPITZ                   white big             39             57.352941
#                         white small           29             42.647059
# STANDARD POODLE         all black             39             36.448598
#                         all brown             31             28.971963
#                         all white             37             34.579439
# TOY POODLE              all black             31             34.065934
#                         all brown             30             32.967033
#                         all white             30             32.967033
# WELSH CORGI             black white           31             36.470588
#                         brown white           26             30.588235
#                         tricolor              28             32.941176
# YORKSHIRE TERRIER       long hair             28             53.846154
#                         short hair            24             46.153846
#
#                                            breed_in_color_ratio
# breed                   color
# AMERICAN COCKER SPANIEL all black                     12.686567
#                         all brown                     17.801047
#                         all white                      8.223684
#                         black white                   10.580205
# BEDLINGTON TERRIER      grey                          42.857143
#                         white                         21.794872
# BICHON                  white m                      100.000000
#                         white o                      100.000000
# BULLDOG                 black white                    8.873720
#                         brown white                   24.074074
#                         white                         21.794872
# CAVALIER COCKER SPANIEL big                          100.000000
#                         small                        100.000000
# CHIHUAHUA               all black                     11.567164
#                         all brown                     14.136126
#                         all white                     10.197368
#                         black brown                   17.647059
#                         black white                    8.873720
#                         brown white                   19.753086
# CHOW CHOW               black                         34.951456
#                         brown                         39.130435
#                         white                         21.794872
# DOBERMANN               black brown                   20.915033
# FRENCH BULLDOG          all black                     11.940299
#                         all white                     12.500000
#                         black chest white            100.000000
#                         black white                   14.675768
#                         brown mouth black            100.000000
# GERMAN SHEPHERD DOG     black brown                   20.915033
# GOLDEN RETRIEVER        brown                         36.956522
#                         light brown                  100.000000
#                         white                         19.871795
# HUSKY                   black white                   12.969283
#                         grey white                   100.000000
# ITALIAN GREY HOUND      black                         29.126214
#                         brown                         23.913043
#                         grey                          57.142857
# JINDO                   all brown big                100.000000
#                         all brown small              100.000000
#                         all white big                100.000000
#                         all white small              100.000000
#                         black brown big              100.000000
#                         black brown small            100.000000
# LABRADOR                all black                     15.298507
#                         all white                     13.815789
#                         all yellow                   100.000000
# MALTESE                 white long hair              100.000000
#                         white short hair             100.000000
# PEKINGESE               all black                     12.686567
#                         all brown                     18.324607
#                         all white                     12.828947
#                         white mouth black             42.622951
# POMERANIAN              all black                      9.701493
#                         all brown                     17.801047
#                         all white                     10.855263
#                         black brown                   16.339869
#                         black white                   13.993174
#                         brown white                   17.283951
# PUG                     black                         35.922330
#                         white mouth black             57.377049
# ROTTWEILER              black brown                   24.183007
# SAMOYED                 white big                     44.285714
# SHETLAND SHEEPDOG       black white                    9.556314
#                         tricolor                      58.208955
# SHIBA                   black white                    9.897611
#                         brown white                   22.839506
#                         white                         14.743590
# SHIH TZU                all white                      9.539474
#                         white o o                    100.000000
# SPITZ                   white big                     55.714286
#                         white small                  100.000000
# STANDARD POODLE         all black                     14.552239
#                         all brown                     16.230366
#                         all white                     12.171053
# TOY POODLE              all black                     11.567164
#                         all brown                     15.706806
#                         all white                      9.868421
# WELSH CORGI             black white                   10.580205
#                         brown white                   16.049383
#                         tricolor                      41.791045
# YORKSHIRE TERRIER       long hair                    100.000000
#                         short hair                   100.000000

# %%
df.sort_values(by=['count'], ascending=False, axis=0).reset_index().drop('index', axis=1)
# Out:
#                       breed              color count       ratio
# 0            FRENCH BULLDOG        black white    43   0.0161959
# 1                  LABRADOR          all white    42   0.0158192
# 2                POMERANIAN        black white    41   0.0154426
# 3                  LABRADOR          all black    41   0.0154426
# 4                   MALTESE   white short hair    41   0.0154426
# 5                     JINDO      all brown big    40   0.0150659
# 6                   BULLDOG        brown white    39   0.0146893
# 7           STANDARD POODLE          all black    39   0.0146893
# 8                     SPITZ          white big    39   0.0146893
# 9                 PEKINGESE          all white    39   0.0146893
# 10        SHETLAND SHEEPDOG           tricolor    39   0.0146893
# 11                    JINDO    all white small    38   0.0143126
# 12                    HUSKY        black white    38   0.0143126
# 13           FRENCH BULLDOG          all white    38   0.0143126
# 14                      PUG              black    37    0.013936
# 15  CAVALIER COCKER SPANIEL                big    37    0.013936
# 16          STANDARD POODLE          all white    37    0.013936
# 17               ROTTWEILER        black brown    37    0.013936
# 18                    SHIBA        brown white    37    0.013936
# 19       ITALIAN GREY HOUND               grey    36   0.0135593
# 20           FRENCH BULLDOG  black chest white    36   0.0135593
# 21                CHOW CHOW              brown    36   0.0135593
# 22                CHOW CHOW              black    36   0.0135593
# 23                  MALTESE    white long hair    36   0.0135593
# 24                PEKINGESE          all brown    35   0.0131827
# 25                      PUG  white mouth black    35   0.0131827
# 26  AMERICAN COCKER SPANIEL          all brown    34    0.012806
# 27                    JINDO      all white big    34    0.012806
# 28               POMERANIAN          all brown    34    0.012806
# 29                 LABRADOR         all yellow    34    0.012806
# 30                PEKINGESE          all black    34    0.012806
# 31  AMERICAN COCKER SPANIEL          all black    34    0.012806
# 32         GOLDEN RETRIEVER              brown    34    0.012806
# 33                  BULLDOG              white    34    0.012806
# 34                CHOW CHOW              white    34    0.012806
# 35       BEDLINGTON TERRIER              white    34    0.012806
# 36               POMERANIAN          all white    33   0.0124294
# 37      GERMAN SHEPHERD DOG        black brown    32   0.0120527
# 38                    JINDO    all brown small    32   0.0120527
# 39           FRENCH BULLDOG          all black    32   0.0120527
# 40                DOBERMANN        black brown    32   0.0120527
# 41                CHIHUAHUA        brown white    32   0.0120527
# 42                   BICHON            white o    32   0.0120527
# 43              WELSH CORGI        black white    31   0.0116761
# 44  AMERICAN COCKER SPANIEL        black white    31   0.0116761
# 45                  SAMOYED          white big    31   0.0116761
# 46               TOY POODLE          all black    31   0.0116761
# 47         GOLDEN RETRIEVER              white    31   0.0116761
# 48                CHIHUAHUA          all black    31   0.0116761
# 49                CHIHUAHUA          all white    31   0.0116761
# 50           FRENCH BULLDOG  brown mouth black    31   0.0116761
# 51          STANDARD POODLE          all brown    31   0.0116761
# 52                 SHIH TZU          white o o    30   0.0112994
# 53               TOY POODLE          all brown    30   0.0112994
# 54               TOY POODLE          all white    30   0.0112994
# 55       ITALIAN GREY HOUND              black    30   0.0112994
# 56                    SHIBA        black white    29   0.0109228
# 57                    SPITZ        white small    29   0.0109228
# 58                 SHIH TZU          all white    29   0.0109228
# 59                    JINDO    black brown big    29   0.0109228
# 60                    HUSKY         grey white    29   0.0109228
# 61  CAVALIER COCKER SPANIEL              small    29   0.0109228
# 62               POMERANIAN        brown white    28   0.0105461
# 63        SHETLAND SHEEPDOG        black white    28   0.0105461
# 64        YORKSHIRE TERRIER          long hair    28   0.0105461
# 65              WELSH CORGI           tricolor    28   0.0105461
# 66                    JINDO  black brown small    28   0.0105461
# 67                   BICHON            white m    28   0.0105461
# 68                CHIHUAHUA          all brown    27   0.0101695
# 69       BEDLINGTON TERRIER               grey    27   0.0101695
# 70                CHIHUAHUA        black brown    27   0.0101695
# 71         GOLDEN RETRIEVER        light brown    27   0.0101695
# 72                CHIHUAHUA        black white    26  0.00979284
# 73                  BULLDOG        black white    26  0.00979284
# 74              WELSH CORGI        brown white    26  0.00979284
# 75                PEKINGESE  white mouth black    26  0.00979284
# 76               POMERANIAN          all black    26  0.00979284
# 77               POMERANIAN        black brown    25   0.0094162
# 78  AMERICAN COCKER SPANIEL          all white    25   0.0094162
# 79        YORKSHIRE TERRIER         short hair    24  0.00903955
# 80                    SHIBA              white    23   0.0086629
# 81       ITALIAN GREY HOUND              brown    22  0.00828625

# %%
# 전체 품종별 비율
breedratio = pd.DataFrame(df.groupby('breed')['count'].sum()).reset_index()
breedratio['ratio'] = breedratio['count']/breedratio['count'].sum()*100
breedratio = breedratio.sort_values(by=['ratio'], ascending=False, axis=0).reset_index().drop('index', axis=1)
breedratio
# Out:
#                       breed  count     ratio
# 0                     JINDO    201  7.570621
# 1                POMERANIAN    187  7.043315
# 2            FRENCH BULLDOG    180  6.779661
# 3                 CHIHUAHUA    174  6.553672
# 4                 PEKINGESE    134  5.047081
# 5   AMERICAN COCKER SPANIEL    124  4.670433
# 6                  LABRADOR    117  4.406780
# 7           STANDARD POODLE    107  4.030132
# 8                 CHOW CHOW    106  3.992467
# 9                   BULLDOG     99  3.728814
# 10         GOLDEN RETRIEVER     92  3.465160
# 11               TOY POODLE     91  3.427495
# 12                    SHIBA     89  3.352166
# 13       ITALIAN GREY HOUND     88  3.314501
# 14              WELSH CORGI     85  3.201507
# 15                  MALTESE     77  2.900188
# 16                      PUG     72  2.711864
# 17                    SPITZ     68  2.561205
# 18        SHETLAND SHEEPDOG     67  2.523540
# 19                    HUSKY     67  2.523540
# 20  CAVALIER COCKER SPANIEL     66  2.485876
# 21       BEDLINGTON TERRIER     61  2.297552
# 22                   BICHON     60  2.259887
# 23                 SHIH TZU     59  2.222222
# 24        YORKSHIRE TERRIER     52  1.958569
# 25               ROTTWEILER     37  1.393597
# 26      GERMAN SHEPHERD DOG     32  1.205273
# 27                DOBERMANN     32  1.205273
# 28                  SAMOYED     31  1.167608

# %%
# 전체 color 비율
colorratio = pd.DataFrame(df.groupby('color')['count'].sum()).reset_index()
colorratio['ratio'] = colorratio['count']/colorratio['count'].sum()*100
colorratio.sort_values(by=['ratio'], ascending=False, axis=0)
# Out:
#                 color  count      ratio
# 4           all white    304  11.450094
# 14        black white    293  11.035782
# 0           all black    268  10.094162
# 1           all brown    191   7.193974
# 17        brown white    162   6.101695
# 25              white    156   5.875706
# 10        black brown    153   5.762712
# 9               black    103   3.879473
# 15              brown     92   3.465160
# 26          white big     70   2.636535
# 24           tricolor     67   2.523540
# 18               grey     63   2.372881
# 29  white mouth black     61   2.297552
# 32   white short hair     41   1.544256
# 2       all brown big     40   1.506591
# 6     all white small     38   1.431262
# 8                 big     37   1.393597
# 13  black chest white     36   1.355932
# 27    white long hair     36   1.355932
# 7          all yellow     34   1.280603
# 5       all white big     34   1.280603
# 3     all brown small     32   1.205273
# 30            white o     32   1.205273
# 16  brown mouth black     31   1.167608
# 31          white o o     30   1.129944
# 19         grey white     29   1.092279
# 23              small     29   1.092279
# 11    black brown big     29   1.092279
# 33        white small     29   1.092279
# 28            white m     28   1.054614
# 21          long hair     28   1.054614
# 12  black brown small     28   1.054614
# 20        light brown     27   1.016949
# 22         short hair     24   0.903955

# %%
# donut graph
plt.figure(figsize=(40, 40))
plt.rc('font', family='NanumGothic')
plt.rcParams['font.size'] = 15
fig, ax = plt.subplots()
size = 2

cmap = plt.get_cmap("Pastel2")
outer_colors = cmap(np.arange(8))
inner_colors = cmap(np.arange(8))

# 각 품종 내 color
ax.pie(pd.DataFrame(breedratio['breed']).merge(pd.DataFrame(df.groupby(['breed', 'color'])['count'].sum()).reset_index())['count'], labels=pd.DataFrame(breedratio['breed']).merge(pd.DataFrame(df.groupby(['breed', 'color'])['count'].sum()).reset_index())['color'], radius=5-size, colors=inner_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=0.9, startangle=90)

# 전체 품종
ax.pie(pd.DataFrame(breedratio['breed']).merge(pd.DataFrame(df.groupby('breed')['count'].sum()).reset_index())['count'], labels=pd.DataFrame(breedratio['breed']).merge(pd.DataFrame(df.groupby('breed')['count'].sum()).reset_index())['breed'], radius=5, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=1.05, startangle=90)

plt.show()

# %%
#df = pd.DataFrame(breedratio['breed']).merge(df)
# donut graph
plt.figure(figsize=(40, 40))
plt.rc('font', family='NanumGothic')
plt.rcParams['font.size'] = 15
fig, ax = plt.subplots()
size = 5

cmap = plt.get_cmap("Pastel2")
outer_colors = cmap(np.arange(8))

# 전체 품종
ax.pie(breedratio['count'], labels=breedratio['breed'], radius=5, colors=outer_colors, wedgeprops=dict(width=size, edgecolor='w'), labeldistance=1.05, startangle=90)

plt.show()
