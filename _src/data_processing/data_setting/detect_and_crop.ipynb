# %% [markdown]
# # Detect and crop images
# - using model pre-trained on COCO

# %%
import torchvision
import numpy
from PIL import Image
import cv2
import torchvision.transforms as T
import matplotlib.pyplot as plt
import os 
model = torchvision.models.detection.fasterrcnn_resnet50_fpn(pretrained=True)
model.eval()
# Out:
# FasterRCNN(
#   (transform): GeneralizedRCNNTransform(
#       Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
#       Resize(min_size=(800,), max_size=1333, mode='bilinear')
#   )
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d(64)
#       (relu): ReLU(inplace=True)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d(256)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(64)
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(64)
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(256)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(512)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(128)
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(128)
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(512)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(1024)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(256)
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(256)
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(1024)
#           (relu): ReLU(inplace=True)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d(2048)
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d(512)
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d(512)
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d(2048)
#           (relu): ReLU(inplace=True)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign()
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=91, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=364, bias=True)
#     )
#   )
# )

# %%
# label list => we are using 'dog' or 'cat'
COCO_INSTANCE_CATEGORY_NAMES = [
    '__background__', 'person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus',
    'train', 'truck', 'boat', 'traffic light', 'fire hydrant', 'N/A', 'stop sign',
    'parking meter', 'bench', 'bird', 'cat', 'dog', 'horse', 'sheep', 'cow',
    'elephant', 'bear', 'zebra', 'giraffe', 'N/A', 'backpack', 'umbrella', 'N/A', 'N/A',
    'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', 'sports ball',
    'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', 'tennis racket',
    'bottle', 'N/A', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl',
    'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza',
    'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'N/A', 'dining table',
    'N/A', 'N/A', 'toilet', 'N/A', 'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone',
    'microwave', 'oven', 'toaster', 'sink', 'refrigerator', 'N/A', 'book',
    'clock', 'vase', 'scissors', 'teddy bear', 'hair drier', 'toothbrush'
]

# %%
# prediction + bounding box 좌표 찾기, 한국어 경로 지원
# 강아지 검출이 안됐을 시 error = 1 로 설정.
def get_prediction(img_path, threshold):
    stream = open( img_path.encode("utf-8") , "rb")
    bytes = bytearray(stream.read())
    numpyArray = numpy.asarray(bytes, dtype=numpy.uint8)
    img = cv2.imdecode(numpyArray , cv2.IMREAD_UNCHANGED)
    src = img.copy() 
    error = 0 
   # img = Image.open(img_path) # Load the image
    transform = T.Compose([T.ToTensor()]) # Defing PyTorch Transform
    img = transform(img) # Apply the transform to the image
    pred = model([img]) # Pass the image to the model
    pred_class = [COCO_INSTANCE_CATEGORY_NAMES[i] for i in list(pred[0]['labels'].numpy())] # Get the Prediction Score
    pred_boxes = [[(i[0], i[1]), (i[2], i[3])] for i in list(pred[0]['boxes'].detach().numpy())] # Bounding boxes
    pred_score = list(pred[0]['scores'].detach().numpy())
    try:
        pred_t = [pred_score.index(x) for x in pred_score if x > threshold][-1] # Get list of index with score greater than threshold.
    except IndexError as e:
        print(e, ' 강아지 검출 x')
        error = 1
        pred_t = 0
    pred_boxes = pred_boxes[:pred_t+1]
    pred_class = pred_class[:pred_t+1]
    return pred_boxes, pred_class, src, error

# %%
# bbox 좌표를 더 크게 잡아서 crop 함수로 전달 
def object_detection_api(img_path, threshold=0.8, rect_th=1, text_size=1, text_th=1):
    boxes, pred_cls, img, error = get_prediction(img_path, threshold) # Get predictions
    if error == 1:
        return (0,0),(0,0),0,error
    img2 = img
    for i in range(len(boxes)):
        if pred_cls[i] == 'dog':
            #cv2.rectangle(img, boxes[i][0], boxes[i][1],color=(0, 255, 0), thickness=rect_th) # Draw Rectangle with the coordinates
            print(pred_cls)
            print(boxes[i][0],boxes[i][1])
            lt = boxes[i][0]
            ld = (boxes[i][0][0], boxes[i][1][1])
            rt = (boxes[i][1][0], boxes[i][0][1])
            rd = boxes[i][1]
#             print('left top = ' , lt)
#             print('left down = ' , ld)
#             print('right top = ' , rt)
#             print('right down = ' , rd)
            #cv2.putText(img,pred_cls[i], boxes[i][0],  cv2.FONT_HERSHEY_SIMPLEX, text_size, (0,255,0),thickness=text_th) # Write the prediction class
            if int(lt[0] - 20) < 0:
                broad_lt_0 = 0
            else:
                broad_lt_0 = int(lt[0] - 20)
            if int(lt[1] - 20) < 0:
                broad_lt_1 = 0
            else:
                broad_lt_1 = int(lt[1] - 20)
        
            boxes_broad_lt = (broad_lt_0 , broad_lt_1)
            boxes_broad_rd = (int(rd[0] + 20) , int(rd[1] + 20) )
    #plt.figure(figsize=(30,30)) # display the output image
    #plt.imshow(img)
    return boxes_broad_lt, boxes_broad_rd, img2, error

# %%
# 한국어 경로 지원되는 image write 함수
def imwrite(filename, img, params=None):
    try:
        ext = os.path.splitext(filename)[1]
        result, n = cv2.imencode(ext, img, params)
        
        if result:
            with open(filename, mode='w+b') as f:
                n.tofile(f) 
            return True 
        else:
            return False
    except Exception as e:
        print(e)
        return False

# %%
#  이미지를 size에 맞게 crop후 저장하는 함수 
def crop_save(img_path, dst_name, size= 240):
    lt, rd, src, error = object_detection_api(img_path, threshold=0.9)
    if error == 1:
        return
   # dst_name = img_path.split('/')[-1].split('.jpg')[0] +'_crop'+'.jpg'
    print(lt,rd)
    roi = src[lt[1]:rd[1], lt[0]:rd[0]]
#    plt.imshow(roi)
    print(dst_name)
    dst = cv2.resize(roi, dsize=(size, size), interpolation=cv2.INTER_AREA)
    imwrite(dst_name,dst)

# %%
# main code
# 대상 이미지 class가 모여있는 폴더를 path_file에 입력. 
path_file = './' + 'sample'

for count, foldername in enumerate(os.listdir(path_file)): 
    print(count, foldername)
    for count, filename in enumerate(os.listdir(path_file+ '/' +foldername)): 
        print(count, filename)
        dst_name = filename.split('/')[-1].split('.jpg')[0] +'_crop'+'.jpg'
        path_src_file = path_file+'/'+foldername + '/'+filename
        path_dst_file =  path_file +'/'+foldername + '/'+ dst_name
        print(path_src_file)
        crop_save(path_src_file, path_dst_file)
# Out:
# 0 골든_리트리버
# 0 고골든_리트리버_경기-성남-2020-00499.jpg
# ./sample/골든_리트리버/고골든_리트리버_경기-성남-2020-00499.jpg
# 1 골든_리트리버_강원-춘천-2020-00366.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-춘천-2020-00366.jpg
# 2 골든_리트리버_강원-춘천-2020-00366_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-춘천-2020-00366_crop.jpg
# 3 골든_리트리버_강원-춘천-2020-00371.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-춘천-2020-00371.jpg
# 4 골든_리트리버_강원-춘천-2020-00371_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-춘천-2020-00371_crop.jpg
# 5 골든_리트리버_강원-횡성-2020-00114.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-횡성-2020-00114.jpg
# 6 골든_리트리버_강원-횡성-2020-00114_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_강원-횡성-2020-00114_crop.jpg
# 7 골든_리트리버_경기-가평-2020-00184.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-가평-2020-00184.jpg
# 8 골든_리트리버_경기-가평-2020-00184_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-가평-2020-00184_crop.jpg
# 9 골든_리트리버_경기-고양-2020-00757.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-고양-2020-00757.jpg
# 10 골든_리트리버_경기-고양-2020-00757_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-고양-2020-00757_crop.jpg
# 11 골든_리트리버_경기-부천-2020-00772.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-부천-2020-00772.jpg
# 12 골든_리트리버_경기-부천-2020-00772_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-부천-2020-00772_crop.jpg
# 13 골든_리트리버_경기-수원-2020-00685.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-수원-2020-00685.jpg
# 14 골든_리트리버_경기-수원-2020-00685_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-수원-2020-00685_crop.jpg
# 15 골든_리트리버_경기-수원-2020-00696.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-수원-2020-00696.jpg
# 16 골든_리트리버_경기-수원-2020-00700.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-수원-2020-00700.jpg
# 17 골든_리트리버_경기-수원-2020-00700_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-수원-2020-00700_crop.jpg
# 18 골든_리트리버_경기-안성-2020-00689.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-안성-2020-00689.jpg
# 19 골든_리트리버_경기-안성-2020-00689_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-안성-2020-00689_crop.jpg
# 20 골든_리트리버_경기-안양-2020-00210.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-안양-2020-00210.jpg
# 21 골든_리트리버_경기-안양-2020-00210_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-안양-2020-00210_crop.jpg
# 22 골든_리트리버_경기-양평-2020-00301.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-양평-2020-00301.jpg
# 23 골든_리트리버_경기-양평-2020-00301_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-양평-2020-00301_crop.jpg
# 24 골든_리트리버_경기-용인-2020-00463.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00463.jpg
# 25 골든_리트리버_경기-용인-2020-00463_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00463_crop.jpg
# 26 골든_리트리버_경기-용인-2020-00501.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00501.jpg
# 27 골든_리트리버_경기-용인-2020-00501_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00501_crop.jpg
# 28 골든_리트리버_경기-용인-2020-00561.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00561.jpg
# 29 골든_리트리버_경기-용인-2020-00561_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-용인-2020-00561_crop.jpg
# 30 골든_리트리버_경기-이천-2020-00509.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-이천-2020-00509.jpg
# 31 골든_리트리버_경기-이천-2020-00509_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-이천-2020-00509_crop.jpg
# 32 골든_리트리버_경기-포천-2020-00578.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-포천-2020-00578.jpg
# 33 골든_리트리버_경기-포천-2020-00578_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-포천-2020-00578_crop.jpg
# 34 골든_리트리버_경기-하남-2020-00356.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-하남-2020-00356.jpg
# 35 골든_리트리버_경기-하남-2020-00356_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-하남-2020-00356_crop.jpg
# 36 골든_리트리버_경기-하남-2020-00370.jpg
# ./sample/골든_리트리버/골든_리트리버_경기-하남-2020-00370.jpg
# 37 골든_리트리버_경남-거창-2020-00276.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-거창-2020-00276.jpg
# 38 골든_리트리버_경남-거창-2020-00276_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-거창-2020-00276_crop.jpg
# 39 골든_리트리버_경남-양산-2020-00210.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-양산-2020-00210.jpg
# 40 골든_리트리버_경남-양산-2020-00210_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-양산-2020-00210_crop.jpg
# 41 골든_리트리버_경남-창원3-2020-00264.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-창원3-2020-00264.jpg
# 42 골든_리트리버_경남-창원3-2020-00271.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-창원3-2020-00271.jpg
# 43 골든_리트리버_경남-창원3-2020-00271_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-창원3-2020-00271_crop.jpg
# 44 골든_리트리버_경남-통영-2020-00347.jpg
# ./sample/골든_리트리버/골든_리트리버_경남-통영-2020-00347.jpg
# 45 골든_리트리버_경북-경산-2020-00665.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-경산-2020-00665.jpg
# 46 골든_리트리버_경북-경산-2020-00665_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-경산-2020-00665_crop.jpg
# 47 골든_리트리버_경북-경주-2020-00684.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-경주-2020-00684.jpg
# 48 골든_리트리버_경북-경주-2020-00684_crop.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-경주-2020-00684_crop.jpg
# 49 골든_리트리버_경북-경주-2020-00736.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-경주-2020-00736.jpg
# 50 골든_리트리버_경북-영천-2020-00113.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-영천-2020-00113.jpg
# 51 골든_리트리버_경북-예천-2020-00082.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-예천-2020-00082.jpg
# 52 골든_리트리버_경북-예천-2020-00088.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-예천-2020-00088.jpg
# 53 골든_리트리버_경북-포항-2020-00942.jpg
# ./sample/골든_리트리버/골든_리트리버_경북-포항-2020-00942.jpg
# 54 골든_리트리버_대구-수성-2020-00608.jpg
# ./sample/골든_리트리버/골든_리트리버_대구-수성-2020-00608.jpg
# 55 골든_리트리버_대전-동구-2020-00376.jpg
# ./sample/골든_리트리버/골든_리트리버_대전-동구-2020-00376.jpg
# 56 골든_리트리버_대전-동구-2020-00421.jpg
# ./sample/골든_리트리버/골든_리트리버_대전-동구-2020-00421.jpg
# 57 골든_리트리버_대전-유성-2020-00443.jpg
# ./sample/골든_리트리버/골든_리트리버_대전-유성-2020-00443.jpg
# 58 골든_리트리버_대전-중구-2020-00425.jpg
# ./sample/골든_리트리버/골든_리트리버_대전-중구-2020-00425.jpg
# 59 골든_리트리버_부산-남구-2020-00244.jpg
# ./sample/골든_리트리버/골든_리트리버_부산-남구-2020-00244.jpg
# 60 골든_리트리버_부산-남구-2020-00266.jpg
# ./sample/골든_리트리버/골든_리트리버_부산-남구-2020-00266.jpg
# 61 골든_리트리버_서울-동작-2020-00171.jpg
# ./sample/골든_리트리버/골든_리트리버_서울-동작-2020-00171.jpg
# 62 골든_리트리버_서울-동작-2020-00172.jpg
# ./sample/골든_리트리버/골든_리트리버_서울-동작-2020-00172.jpg
# 63 골든_리트리버_인천-남동-2020-00402.jpg
# ./sample/골든_리트리버/골든_리트리버_인천-남동-2020-00402.jpg
# 64 골든_리트리버_인천-부평-2020-00630.jpg
# ./sample/골든_리트리버/골든_리트리버_인천-부평-2020-00630.jpg
# 65 골든_리트리버_전남-순천-2020-00305.jpg
# ./sample/골든_리트리버/골든_리트리버_전남-순천-2020-00305.jpg
# 66 골든_리트리버_전남-여수-2020-00306.jpg
# ./sample/골든_리트리버/골든_리트리버_전남-여수-2020-00306.jpg
# 67 골든_리트리버_전남-장성-2020-00216.jpg
# ./sample/골든_리트리버/골든_리트리버_전남-장성-2020-00216.jpg
# 68 골든_리트리버_전북-군산-2020-01058.jpg
# ./sample/골든_리트리버/골든_리트리버_전북-군산-2020-01058.jpg
# 69 골든_리트리버_전북-김제-2020-00256.jpg
# ./sample/골든_리트리버/골든_리트리버_전북-김제-2020-00256.jpg
# 70 골든_리트리버_전북-남원-2020-00392.jpg
# ./sample/골든_리트리버/골든_리트리버_전북-남원-2020-00392.jpg
# 71 골든_리트리버_전북-전주-2020-01276.jpg
# ./sample/골든_리트리버/골든_리트리버_전북-전주-2020-01276.jpg
# 72 골든_리트리버_전북-정읍-2020-00442.jpg
# ./sample/골든_리트리버/골든_리트리버_전북-정읍-2020-00442.jpg
# 73 골든_리트리버_제주-제주-2020-03984.jpg
# ./sample/골든_리트리버/골든_리트리버_제주-제주-2020-03984.jpg
# 74 골든_리트리버_충남-보령-2020-00276.jpg
# ./sample/골든_리트리버/골든_리트리버_충남-보령-2020-00276.jpg
# 75 골든_리트리버_충남-부여-2020-00279.jpg
# ./sample/골든_리트리버/골든_리트리버_충남-부여-2020-00279.jpg
# 76 골든_리트리버_충남-서천-2020-00140.jpg
# ./sample/골든_리트리버/골든_리트리버_충남-서천-2020-00140.jpg
# 77 골든_리트리버_충남-천안-2020-00723.jpg
# ./sample/골든_리트리버/골든_리트리버_충남-천안-2020-00723.jpg
# 78 골든_리트리버_충남-태안-2020-00267.jpg
# ./sample/골든_리트리버/골든_리트리버_충남-태안-2020-00267.jpg
# 79 골든_리트리버_충북-음성-2020-00250.jpg
# ./sample/골든_리트리버/골든_리트리버_충북-음성-2020-00250.jpg
# 80 골든_리트리버_충북-진천-2020-00186.jpg
# ./sample/골든_리트리버/골든_리트리버_충북-진천-2020-00186.jpg
# 81 골든_리트리버_충북-청주-2020-01079.jpg
# ./sample/골든_리트리버/골든_리트리버_충북-청주-2020-01079.jpg
# 82 골든_리트리버_충북-충주-2020-00296.jpg
# ./sample/골든_리트리버/골든_리트리버_충북-충주-2020-00296.jpg
# 83 골든_리트리버_충북-충주-2020-00341.jpg
# ./sample/골든_리트리버/골든_리트리버_충북-충주-2020-00341.jpg
# 1 그레이_하운드
# 0 그레이_하운드_강원-고성-2020-00142.jpg
# ./sample/그레이_하운드/그레이_하운드_강원-고성-2020-00142.jpg
# 1 그레이_하운드_경기-가평-2020-00161.jpg
# ./sample/그레이_하운드/그레이_하운드_경기-가평-2020-00161.jpg
# 2 그레이_하운드_경기-평택-2020-01597.jpg
# ./sample/그레이_하운드/그레이_하운드_경기-평택-2020-01597.jpg
# 3 그레이_하운드_경남-창원2-2020-00328.jpg
# ./sample/그레이_하운드/그레이_하운드_경남-창원2-2020-00328.jpg
# 4 그레이_하운드_경북-포항-2020-00943.jpg
# ./sample/그레이_하운드/그레이_하운드_경북-포항-2020-00943.jpg
# 5 그레이_하운드_울산-북구-2020-00245.jpg
# ./sample/그레이_하운드/그레이_하운드_울산-북구-2020-00245.jpg
# 6 그레이_하운드_울산-울주-2020-00624.jpg
# ./sample/그레이_하운드/그레이_하운드_울산-울주-2020-00624.jpg
# 7 그레이_하운드_충북-음성-2020-00249.jpg
# ./sample/그레이_하운드/그레이_하운드_충북-음성-2020-00249.jpg
# 2 그레이트_덴
# 0 그레이트_덴_경기-화성-2020-01362.jpg
# ./sample/그레이트_덴/그레이트_덴_경기-화성-2020-01362.jpg
# 3 그레이트_피레니즈
# 0 그레이트_피레니즈_강원-춘천-2020-00356.jpg
# ./sample/그레이트_피레니즈/그레이트_피레니즈_강원-춘천-2020-00356.jpg
# 1 그레이트_피레니즈_경기-광주-2020-00613.jpg
# ./sample/그레이트_피레니즈/그레이트_피레니즈_경기-광주-2020-00613.jpg
# 2 그레이트_피레니즈_경기-평택-2020-01679.jpg
# ./sample/그레이트_피레니즈/그레이트_피레니즈_경기-평택-2020-01679.jpg
# 3 그레이트_피레니즈_부산-동래-2020-00272.jpg
# ./sample/그레이트_피레니즈/그레이트_피레니즈_부산-동래-2020-00272.jpg
# 4 그레이트_피레니즈_충북-청주-2020-01117.jpg
# ./sample/그레이트_피레니즈/그레이트_피레니즈_충북-청주-2020-01117.jpg
# 4 기타
# 0 기타_대구-달성-2020-00527.jpg
# ./sample/기타/기타_대구-달성-2020-00527.jpg
# 1 기타_대구-달성-2020-00528.jpg
# ./sample/기타/기타_대구-달성-2020-00528.jpg
# 2 기타_부산-연제-2020-00241.jpg
# ./sample/기타/기타_부산-연제-2020-00241.jpg
# 3 기타_부산-연제-2020-00255.jpg
# ./sample/기타/기타_부산-연제-2020-00255.jpg
# 4 기타_부산-연제-2020-00256.jpg
# ./sample/기타/기타_부산-연제-2020-00256.jpg
# 5 기타_부산-연제-2020-00257.jpg
# ./sample/기타/기타_부산-연제-2020-00257.jpg
# 6 기타_부산-연제-2020-00258.jpg
# ./sample/기타/기타_부산-연제-2020-00258.jpg
# 7 기타_부산-연제-2020-00259.jpg
# ./sample/기타/기타_부산-연제-2020-00259.jpg
# 8 기타_부산-연제-2020-00260.jpg
# ./sample/기타/기타_부산-연제-2020-00260.jpg
# 9 기타_부산-연제-2020-00261.jpg
# ./sample/기타/기타_부산-연제-2020-00261.jpg
# 10 기타_부산-연제-2020-00262.jpg
# ./sample/기타/기타_부산-연제-2020-00262.jpg
# 11 기타_부산-연제-2020-00263.jpg
# ./sample/기타/기타_부산-연제-2020-00263.jpg
# 12 기타_부산-연제-2020-00264.jpg
# ./sample/기타/기타_부산-연제-2020-00264.jpg
# 13 기타_부산-연제-2020-00265.jpg
# ./sample/기타/기타_부산-연제-2020-00265.jpg
# 14 기타_부산-연제-2020-00266.jpg
# ./sample/기타/기타_부산-연제-2020-00266.jpg
# 5 닥스훈트
# 0 닥스훈트_경기-남양주-2020-01047.jpg
# ./sample/닥스훈트/닥스훈트_경기-남양주-2020-01047.jpg
# 1 닥스훈트_경기-성남-2020-00581.jpg
# ./sample/닥스훈트/닥스훈트_경기-성남-2020-00581.jpg
# 2 닥스훈트_경기-수원-2020-00609.jpg
# ./sample/닥스훈트/닥스훈트_경기-수원-2020-00609.jpg
# 3 닥스훈트_경기-수원-2020-00628.jpg
# ./sample/닥스훈트/닥스훈트_경기-수원-2020-00628.jpg
# 4 닥스훈트_경기-수원-2020-00718.jpg
# ./sample/닥스훈트/닥스훈트_경기-수원-2020-00718.jpg
# 5 닥스훈트_경기-안성-2020-00679.jpg
# ./sample/닥스훈트/닥스훈트_경기-안성-2020-00679.jpg
# 6 닥스훈트_경기-양평-2020-00307.jpg
# ./sample/닥스훈트/닥스훈트_경기-양평-2020-00307.jpg
# 7 닥스훈트_경기-오산-2020-00213.jpg
# ./sample/닥스훈트/닥스훈트_경기-오산-2020-00213.jpg
# 8 닥스훈트_경기-의왕-2020-00136.jpg
# ./sample/닥스훈트/닥스훈트_경기-의왕-2020-00136.jpg
# 9 닥스훈트_경기-의정부-2020-00271.jpg
# ./sample/닥스훈트/닥스훈트_경기-의정부-2020-00271.jpg
# 10 닥스훈트_경기-의정부-2020-00284.jpg
# ./sample/닥스훈트/닥스훈트_경기-의정부-2020-00284.jpg
# 11 닥스훈트_경기-이천-2020-00533.jpg
# ./sample/닥스훈트/닥스훈트_경기-이천-2020-00533.jpg
# 12 닥스훈트_경기-평택-2020-01610.jpg
# ./sample/닥스훈트/닥스훈트_경기-평택-2020-01610.jpg
# 13 닥스훈트_경기-화성-2020-01285.jpg
# ./sample/닥스훈트/닥스훈트_경기-화성-2020-01285.jpg
# 14 닥스훈트_경기-화성-2020-01286.jpg
# ./sample/닥스훈트/닥스훈트_경기-화성-2020-01286.jpg
# 15 닥스훈트_경기-화성-2020-01292.jpg
# ./sample/닥스훈트/닥스훈트_경기-화성-2020-01292.jpg
# 16 닥스훈트_경기-화성-2020-01293.jpg
# ./sample/닥스훈트/닥스훈트_경기-화성-2020-01293.jpg
# 17 닥스훈트_경남-김해-2020-01139.jpg
# ./sample/닥스훈트/닥스훈트_경남-김해-2020-01139.jpg
# 18 닥스훈트_경남-양산-2020-00189.jpg
# ./sample/닥스훈트/닥스훈트_경남-양산-2020-00189.jpg
# 19 닥스훈트_경남-통영-2020-00271.jpg
# ./sample/닥스훈트/닥스훈트_경남-통영-2020-00271.jpg
# 20 닥스훈트_경남-통영-2020-00284.jpg
# ./sample/닥스훈트/닥스훈트_경남-통영-2020-00284.jpg
# 21 닥스훈트_경남-하동-2020-00205.jpg
# ./sample/닥스훈트/닥스훈트_경남-하동-2020-00205.jpg
# 22 닥스훈트_경북-성주-2020-00275.jpg
# ./sample/닥스훈트/닥스훈트_경북-성주-2020-00275.jpg
# 23 닥스훈트_경북-영주-2020-00252.jpg
# ./sample/닥스훈트/닥스훈트_경북-영주-2020-00252.jpg
# 24 닥스훈트_경북-영천-2020-00112.jpg
# ./sample/닥스훈트/닥스훈트_경북-영천-2020-00112.jpg
# 25 닥스훈트_광주-서구-2020-00375.jpg
# ./sample/닥스훈트/닥스훈트_광주-서구-2020-00375.jpg
# 26 닥스훈트_대전-대덕-2020-00298.jpg
# ./sample/닥스훈트/닥스훈트_대전-대덕-2020-00298.jpg
# 27 닥스훈트_대전-동구-2020-00393.jpg
# ./sample/닥스훈트/닥스훈트_대전-동구-2020-00393.jpg
# 28 닥스훈트_대전-서구-2020-00473.jpg
# ./sample/닥스훈트/닥스훈트_대전-서구-2020-00473.jpg
# 29 닥스훈트_대전-서구-2020-00474.jpg
# ./sample/닥스훈트/닥스훈트_대전-서구-2020-00474.jpg
# 30 닥스훈트_부산-부산진-2020-00322.jpg
# ./sample/닥스훈트/닥스훈트_부산-부산진-2020-00322.jpg
# 31 닥스훈트_서울-강북-2020-00172.jpg
# ./sample/닥스훈트/닥스훈트_서울-강북-2020-00172.jpg
# 32 닥스훈트_서울-구로-2020-00106.jpg
# ./sample/닥스훈트/닥스훈트_서울-구로-2020-00106.jpg
# 33 닥스훈트_서울-동작-2020-00163.jpg
# ./sample/닥스훈트/닥스훈트_서울-동작-2020-00163.jpg
# 34 닥스훈트_서울-송파-2020-00131.jpg
# ./sample/닥스훈트/닥스훈트_서울-송파-2020-00131.jpg
# 35 닥스훈트_서울-송파-2020-00132.jpg
# ./sample/닥스훈트/닥스훈트_서울-송파-2020-00132.jpg
# 36 닥스훈트_서울-송파-2020-00133.jpg
# ./sample/닥스훈트/닥스훈트_서울-송파-2020-00133.jpg
# 37 닥스훈트_서울-송파-2020-00134.jpg
# ./sample/닥스훈트/닥스훈트_서울-송파-2020-00134.jpg
# 38 닥스훈트_울산-북구-2020-00270.jpg
# ./sample/닥스훈트/닥스훈트_울산-북구-2020-00270.jpg
# 39 닥스훈트_울산-울주-2020-00704.jpg
# ./sample/닥스훈트/닥스훈트_울산-울주-2020-00704.jpg
# 40 닥스훈트_전남-목포-2020-00723.jpg
# ./sample/닥스훈트/닥스훈트_전남-목포-2020-00723.jpg
# 41 닥스훈트_전남-목포-2020-00746.jpg
# ./sample/닥스훈트/닥스훈트_전남-목포-2020-00746.jpg
# 42 닥스훈트_전북-군산-2020-01072.jpg
# ./sample/닥스훈트/닥스훈트_전북-군산-2020-01072.jpg
# 43 닥스훈트_전북-부안-2020-00226.jpg
# ./sample/닥스훈트/닥스훈트_전북-부안-2020-00226.jpg
# 44 닥스훈트_전북-부안-2020-00227.jpg
# ./sample/닥스훈트/닥스훈트_전북-부안-2020-00227.jpg
# 45 닥스훈트_전북-전주-2020-01297.jpg
# ./sample/닥스훈트/닥스훈트_전북-전주-2020-01297.jpg
# 46 닥스훈트_충남-서산-2020-00421.jpg
# ./sample/닥스훈트/닥스훈트_충남-서산-2020-00421.jpg
# 47 닥스훈트_충남-서천-2020-00154.jpg
# ./sample/닥스훈트/닥스훈트_충남-서천-2020-00154.jpg
# 6 달마시안
# 0 달마시안_경남-김해-2020-01023.jpg
# ./sample/달마시안/달마시안_경남-김해-2020-01023.jpg
# 1 달마시안_대전-유성-2020-00411.jpg
# ./sample/달마시안/달마시안_대전-유성-2020-00411.jpg
# 2 달마시안_부산-강서-2020-00421.jpg
# ./sample/달마시안/달마시안_부산-강서-2020-00421.jpg
# 7 도베르만
# 0 도베르만_강원-양구-2020-00025.jpg
# ./sample/도베르만/도베르만_강원-양구-2020-00025.jpg
# 1 도베르만_경기-남양주-2020-01152.jpg
# ./sample/도베르만/도베르만_경기-남양주-2020-01152.jpg
# 2 도베르만_경기-남양주-2020-01153.jpg
# ./sample/도베르만/도베르만_경기-남양주-2020-01153.jpg
# 3 도베르만_경기-이천-2020-00527.jpg
# ./sample/도베르만/도베르만_경기-이천-2020-00527.jpg
# 4 도베르만_전북-완주-2020-00264.jpg
# ./sample/도베르만/도베르만_전북-완주-2020-00264.jpg
# 5 도베르만_제주-제주-2020-03849.jpg
# ./sample/도베르만/도베르만_제주-제주-2020-03849.jpg
# 8 도사
# 0 도사_제주-제주-2020-03868.jpg
# ./sample/도사/도사_제주-제주-2020-03868.jpg
# 9 라브라도_리트리버
# 0 라브라도_리트리버_강원-강릉-2020-00314.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_강원-강릉-2020-00314.jpg
# 1 라브라도_리트리버_강원-강릉-2020-00348.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_강원-강릉-2020-00348.jpg
# 2 라브라도_리트리버_강원-평창-2020-00036.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_강원-평창-2020-00036.jpg
# 3 라브라도_리트리버_강원-평창-2020-00037.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_강원-평창-2020-00037.jpg
# 4 라브라도_리트리버_강원-홍천-2020-00122.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_강원-홍천-2020-00122.jpg
# 5 라브라도_리트리버_경기-광주-2020-00578.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-광주-2020-00578.jpg
# 6 라브라도_리트리버_경기-광주-2020-00579.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-광주-2020-00579.jpg
# 7 라브라도_리트리버_경기-광주-2020-00638.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-광주-2020-00638.jpg
# 8 라브라도_리트리버_경기-광주-2020-00639.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-광주-2020-00639.jpg
# 9 라브라도_리트리버_경기-광주-2020-00649.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-광주-2020-00649.jpg
# 10 라브라도_리트리버_경기-군포-2020-00265.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-군포-2020-00265.jpg
# 11 라브라도_리트리버_경기-군포-2020-00267.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-군포-2020-00267.jpg
# 12 라브라도_리트리버_경기-군포-2020-00278.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-군포-2020-00278.jpg
# 13 라브라도_리트리버_경기-김포-2020-00406.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-김포-2020-00406.jpg
# 14 라브라도_리트리버_경기-남양주-2020-01197.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-남양주-2020-01197.jpg
# 15 라브라도_리트리버_경기-부천-2020-00733.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-부천-2020-00733.jpg
# 16 라브라도_리트리버_경기-성남-2020-00575.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-성남-2020-00575.jpg
# 17 라브라도_리트리버_경기-안산-2020-00983.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-안산-2020-00983.jpg
# 18 라브라도_리트리버_경기-안산-2020-01064.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-안산-2020-01064.jpg
# 19 라브라도_리트리버_경기-양평-2020-00344.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-양평-2020-00344.jpg
# 20 라브라도_리트리버_경기-양평-2020-00352.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-양평-2020-00352.jpg
# 21 라브라도_리트리버_경기-평택-2020-01657.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-평택-2020-01657.jpg
# 22 라브라도_리트리버_경기-포천-2020-00526.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-포천-2020-00526.jpg
# 23 라브라도_리트리버_경기-포천-2020-00536.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-포천-2020-00536.jpg
# 24 라브라도_리트리버_경기-화성-2020-01300.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-화성-2020-01300.jpg
# 25 라브라도_리트리버_경기-화성-2020-01306.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경기-화성-2020-01306.jpg
# 26 라브라도_리트리버_경남-거제-2020-00903.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-거제-2020-00903.jpg
# 27 라브라도_리트리버_경남-거창-2020-00279.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-거창-2020-00279.jpg
# 28 라브라도_리트리버_경남-김해-2020-01080.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-김해-2020-01080.jpg
# 29 라브라도_리트리버_경남-산청-2020-00121.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-산청-2020-00121.jpg
# 30 라브라도_리트리버_경남-창원2-2020-00315.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-창원2-2020-00315.jpg
# 31 라브라도_리트리버_경남-창원3-2020-00265.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-창원3-2020-00265.jpg
# 32 라브라도_리트리버_경남-하동-2020-00163.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경남-하동-2020-00163.jpg
# 33 라브라도_리트리버_경북-경주-2020-00752.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경북-경주-2020-00752.jpg
# 34 라브라도_리트리버_경북-영덕-2020-00192.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경북-영덕-2020-00192.jpg
# 35 라브라도_리트리버_경북-예천-2020-00095.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경북-예천-2020-00095.jpg
# 36 라브라도_리트리버_경북-칠곡-2020-00212.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_경북-칠곡-2020-00212.jpg
# 37 라브라도_리트리버_광주-서구-2020-00313.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_광주-서구-2020-00313.jpg
# 38 라브라도_리트리버_대구-남구-2020-00234.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_대구-남구-2020-00234.jpg
# 39 라브라도_리트리버_대구-달서-2020-00349.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_대구-달서-2020-00349.jpg
# 40 라브라도_리트리버_대구-북구-2020-00253.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_대구-북구-2020-00253.jpg
# 41 라브라도_리트리버_부산-강서-2020-00477.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_부산-강서-2020-00477.jpg
# 42 라브라도_리트리버_서울-관악-2020-00431.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_서울-관악-2020-00431.jpg
# 43 라브라도_리트리버_울산-남구-2020-00494.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_울산-남구-2020-00494.jpg
# 44 라브라도_리트리버_인천-중구-2020-00526.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_인천-중구-2020-00526.jpg
# 45 라브라도_리트리버_전남-목포-2020-00661.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-목포-2020-00661.jpg
# 46 라브라도_리트리버_전남-목포-2020-00755.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-목포-2020-00755.jpg
# 47 라브라도_리트리버_전남-무안-2020-00289.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-무안-2020-00289.jpg
# 48 라브라도_리트리버_전남-무안-2020-00296.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-무안-2020-00296.jpg
# 49 라브라도_리트리버_전남-무안-2020-00308.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-무안-2020-00308.jpg
# 50 라브라도_리트리버_전남-무안-2020-00317.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전남-무안-2020-00317.jpg
# 51 라브라도_리트리버_전북-군산-2020-01006.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전북-군산-2020-01006.jpg
# 52 라브라도_리트리버_전북-완주-2020-00321.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전북-완주-2020-00321.jpg
# 53 라브라도_리트리버_전북-전주-2020-01135.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전북-전주-2020-01135.jpg
# 54 라브라도_리트리버_전북-전주-2020-01345.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_전북-전주-2020-01345.jpg
# 55 라브라도_리트리버_제주-제주-2020-03873.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_제주-제주-2020-03873.jpg
# 56 라브라도_리트리버_충남-당진-2020-00510.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-당진-2020-00510.jpg
# 57 라브라도_리트리버_충남-천안-2020-00673.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-천안-2020-00673.jpg
# 58 라브라도_리트리버_충남-천안-2020-00724.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-천안-2020-00724.jpg
# 59 라브라도_리트리버_충남-천안-2020-00725.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-천안-2020-00725.jpg
# 60 라브라도_리트리버_충남-청양-2020-00068.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-청양-2020-00068.jpg
# 61 라브라도_리트리버_충남-홍성-2020-00490.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충남-홍성-2020-00490.jpg
# 62 라브라도_리트리버_충북-음성-2020-00232.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-음성-2020-00232.jpg
# 63 라브라도_리트리버_충북-음성-2020-00238.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-음성-2020-00238.jpg
# 64 라브라도_리트리버_충북-제천-2020-00228.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-제천-2020-00228.jpg
# 65 라브라도_리트리버_충북-청주-2020-01085.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-청주-2020-01085.jpg
# 66 라브라도_리트리버_충북-청주-2020-01109.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-청주-2020-01109.jpg
# 67 라브라도_리트리버_충북-청주-2020-01166.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-청주-2020-01166.jpg
# 68 라브라도_리트리버_충북-청주-2020-01167.jpg
# ./sample/라브라도_리트리버/라브라도_리트리버_충북-청주-2020-01167.jpg
# 10 라이카
# 0 라이카_경북-경산-2020-00621.jpg
# ./sample/라이카/라이카_경북-경산-2020-00621.jpg
# 1 라이카_경북-경주-2020-00717.jpg
# ./sample/라이카/라이카_경북-경주-2020-00717.jpg
# 11 임시폴더
